# %% [markdown]
# # Information Extraction Performance Analysis
#
# This notebook provides comprehensive analysis of information extraction model performance.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import numpy as np

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
